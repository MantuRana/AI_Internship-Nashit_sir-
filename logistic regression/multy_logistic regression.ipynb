# %%
import numpy as np
import pandas as pd
from sklearn import linear_model

# %%
df= pd.read_csv('BMIdata.csv')
df.head()
# Out:
#    Gender  Height  Weight  Index
# 0    Male     174      96      4
# 1    Male     189      87      2
# 2  Female     185     110      4
# 3  Female     195     104      3
# 4    Male     149      61      3

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le
# Out:
# LabelEncoder()

# %%
a =df

# %%
a['Gender'] = le.fit_transform(a['Gender'])
a
# Out:
#      Gender  Height  Weight  Index
# 0         1     174      96      4
# 1         1     189      87      2
# 2         0     185     110      4
# 3         0     195     104      3
# 4         1     149      61      3
# ..      ...     ...     ...    ...
# 495       0     150     153      5
# 496       0     184     121      4
# 497       0     141     136      5
# 498       1     150      95      5
# 499       1     173     131      5
#
# [500 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train, y_test = train_test_split(df.drop('Index', axis ='columns'),df.Index)

# %%
from sklearn import linear_model
model = linear_model.LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# C:\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([5, 3, 5, 5, 4, 5, 5, 1, 3, 4, 4, 4, 4, 5, 4, 2, 4, 3, 4, 4, 4, 2,
#        4, 4, 5, 3, 3, 5, 2, 5, 2, 3, 5, 5, 5, 3, 5, 3, 5, 2, 4, 5, 3, 3,
#        4, 1, 2, 1, 0, 2, 5, 5, 4, 3, 4, 4, 4, 2, 5, 4, 5, 5, 4, 3, 4, 5,
#        3, 5, 2, 1, 5, 3, 4, 4, 4, 5, 5, 5, 4, 5, 0, 5, 5, 4, 5, 2, 3, 2,
#        4, 4, 5, 4, 5, 5, 5, 5, 2, 5, 4, 5, 4, 5, 5, 2, 4, 4, 4, 4, 5, 4,
#        4, 4, 3, 5, 1, 1, 5, 4, 5, 5, 5, 2, 1, 5, 3], dtype=int64)

# %%
df2 = pd.DataFrame({'orig':y_test, 'pred':y_pred})
df2
# Out:
#      orig  pred
# 28      5     5
# 248     3     3
# 153     5     5
# 65      5     5
# 301     4     4
# ..    ...   ...
# 106     5     5
# 490     2     2
# 358     1     1
# 61      5     5
# 428     4     3
#
# [125 rows x 2 columns]

# %%
df2.to_csv('multy_predicted_data.csv')

# %%
from sklearn.metrics import mean_absolute_error as mae
mae_error = mae(y_test,y_pred)

mae_error
# Out:
# 0.272

# %%
from sklearn.metrics import mean_squared_error as mse
mse_error = mae(y_test,y_pred)

mse_error
# Out:
# 0.272

# %%
model.predict([[1,165,39]]),
# Out:
# C:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# (array([0], dtype=int64),)

# %%
gender = int(input("gender"))
height = int(input("height"))
weight = int(input("weight"))

res = model.predict([[gender,height,weight]])

if(res == 1):print('under weight, pls take more food')
elif(res == 2):print('healthy')
elif(res == 3):print('healthy')
elif(res == 4):print('obbs')
else:print("unvalid")
# Out:
# gender1
# height125
# weight65
# healthy
# C:\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
model.score(x_test,y_test)
# Out:
# 0.744

# %% [markdown]
# # decision tree

# %%
from sklearn import tree

# %%
model1 = tree.DecisionTreeClassifier()
model1
# Out:
# DecisionTreeClassifier()

# %%
model1.fit(df.drop('Index', axis ='columns'),df.Index)
# Out:
# DecisionTreeClassifier()

# %%
y_pred1 = model.predict(x_test)

# %%
y_pred1
# Out:
# array([2, 4, 4, 4, 5, 3, 2, 4, 4, 5, 4, 4, 5, 5, 2, 2, 0, 4, 5, 3, 5, 5,
#        3, 1, 4, 5, 1, 4, 5, 4, 5, 4, 5, 5, 4, 4, 5, 3, 5, 2, 5, 4, 5, 3,
#        2, 3, 4, 4, 4, 4, 2, 4, 3, 4, 3, 2, 5, 0, 5, 4, 5, 5, 5, 5, 3, 5,
#        4, 2, 5, 5, 4, 5, 5, 4, 3, 5, 4, 2, 2, 2, 2, 3, 5, 2, 3, 5, 5, 2,
#        5, 3, 5, 4, 5, 5, 1, 3, 3, 4, 4, 0, 2, 5, 3, 5, 4, 3, 4, 5, 2, 2,
#        2, 5, 4, 5, 4, 1, 4, 4, 3, 2, 5, 5, 5, 5, 4], dtype=int64)

# %%
df1 = pd.DataFrame({'orig':y_test, 'pred':y_pred1})
df1
# Out:
#      orig  pred
# 325     2     2
# 297     4     4
# 108     4     4
# 228     5     4
# 468     5     5
# ..    ...   ...
# 124     5     5
# 480     5     5
# 18      5     5
# 397     5     5
# 16      5     4
#
# [125 rows x 2 columns]

# %%
# from sklearn.metrics import mean_absolute_error as mae
# mae_error = mae(y_test,y_pred)

# mae_error
# Out:
# 0.256

# %%
model.score(x_test,y_test)
# Out:
# 0.72

# %%
import matplotlib.pyplot as plt

# %%
a.head(5)
# Out:
#    Gender  Height  Weight  Index
# 0       1     174      96      4
# 1       1     189      87      2
# 2       0     185     110      4
# 3       0     195     104      3
# 4       1     149      61      3

# %%
fig = plt.figure(figsize=(20,20))
tree.plot_tree(model1, filled =True)
# fig.savefig('tree.png')
# Out:
# [Text(0.7001953125, 0.9583333333333334, 'x[2] <= 122.5\ngini = 0.735\nsamples = 500\nvalue = [13, 22, 69, 68, 130, 198]'),
#  Text(0.4733072916666667, 0.875, 'x[2] <= 83.5\ngini = 0.786\nsamples = 324\nvalue = [13, 22, 69, 68, 97, 55]'),
#  Text(0.2760416666666667, 0.7916666666666666, 'x[1] <= 167.5\ngini = 0.739\nsamples = 149\nvalue = [13, 22, 63, 27, 21, 3]'),
#  Text(0.13541666666666666, 0.7083333333333334, 'x[2] <= 65.0\ngini = 0.699\nsamples = 72\nvalue = [1, 0, 25, 22, 21, 3]'),
#  Text(0.052083333333333336, 0.625, 'x[1] <= 152.0\ngini = 0.398\nsamples = 31\nvalue = [1, 0, 23, 7, 0, 0]'),
#  Text(0.03125, 0.5416666666666666, 'x[2] <= 57.5\ngini = 0.42\nsamples = 10\nvalue = [0, 0, 3, 7, 0, 0]'),
#  Text(0.020833333333333332, 0.4583333333333333, 'x[0] <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.010416666666666666, 0.375, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.03125, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.041666666666666664, 0.4583333333333333, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.07291666666666667, 0.5416666666666666, 'x[1] <= 162.5\ngini = 0.091\nsamples = 21\nvalue = [1, 0, 20, 0, 0, 0]'),
#  Text(0.0625, 0.4583333333333333, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 13, 0, 0, 0]'),
#  Text(0.08333333333333333, 0.4583333333333333, 'x[1] <= 163.5\ngini = 0.219\nsamples = 8\nvalue = [1, 0, 7, 0, 0, 0]'),
#  Text(0.07291666666666667, 0.375, 'x[2] <= 60.0\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1, 0, 0, 0]'),
#  Text(0.0625, 0.2916666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.08333333333333333, 0.2916666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.09375, 0.375, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.21875, 0.625, 'x[1] <= 160.5\ngini = 0.596\nsamples = 41\nvalue = [0, 0, 2, 15, 21, 3]'),
#  Text(0.15625, 0.5416666666666666, 'x[1] <= 141.5\ngini = 0.495\nsamples = 28\nvalue = [0, 0, 1, 5, 19, 3]'),
#  Text(0.125, 0.4583333333333333, 'x[2] <= 77.5\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 0, 1, 3]'),
#  Text(0.11458333333333333, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.13541666666666666, 0.375, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 3]'),
#  Text(0.1875, 0.4583333333333333, 'x[2] <= 72.5\ngini = 0.392\nsamples = 24\nvalue = [0, 0, 1, 5, 18, 0]'),
#  Text(0.15625, 0.375, 'x[1] <= 148.5\ngini = 0.486\nsamples = 12\nvalue = [0, 0, 0, 5, 7, 0]'),
#  Text(0.14583333333333334, 0.2916666666666667, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 6, 0]'),
#  Text(0.16666666666666666, 0.2916666666666667, 'x[1] <= 150.5\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 0, 5, 1, 0]'),
#  Text(0.15625, 0.20833333333333334, 'x[2] <= 68.0\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.14583333333333334, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.16666666666666666, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.17708333333333334, 0.20833333333333334, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.21875, 0.375, 'x[0] <= 0.5\ngini = 0.153\nsamples = 12\nvalue = [0, 0, 1, 0, 11, 0]'),
#  Text(0.20833333333333334, 0.2916666666666667, 'x[2] <= 78.5\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 0, 4, 0]'),
#  Text(0.19791666666666666, 0.20833333333333334, 'x[2] <= 77.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.1875, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.20833333333333334, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.21875, 0.20833333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.22916666666666666, 0.2916666666666667, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 7, 0]'),
#  Text(0.28125, 0.5416666666666666, 'x[2] <= 81.0\ngini = 0.379\nsamples = 13\nvalue = [0, 0, 1, 10, 2, 0]'),
#  Text(0.2708333333333333, 0.4583333333333333, 'x[2] <= 69.0\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 1, 10, 0, 0]'),
#  Text(0.2604166666666667, 0.375, 'x[0] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.25, 0.2916666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2708333333333333, 0.2916666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.28125, 0.375, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]'),
#  Text(0.2916666666666667, 0.4583333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.4166666666666667, 0.7083333333333334, 'x[2] <= 66.0\ngini = 0.646\nsamples = 77\nvalue = [12, 22, 38, 5, 0, 0]'),
#  Text(0.34375, 0.625, 'x[2] <= 55.0\ngini = 0.62\nsamples = 40\nvalue = [12, 20, 8, 0, 0, 0]'),
#  Text(0.3229166666666667, 0.5416666666666666, 'x[1] <= 179.5\ngini = 0.475\nsamples = 18\nvalue = [12, 5, 1, 0, 0, 0]'),
#  Text(0.3125, 0.4583333333333333, 'x[1] <= 169.5\ngini = 0.278\nsamples = 6\nvalue = [0, 5, 1, 0, 0, 0]'),
#  Text(0.3020833333333333, 0.375, 'x[0] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.2916666666666667, 0.2916666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3125, 0.2916666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.3229166666666667, 0.375, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0, 0, 0]'),
#  Text(0.3333333333333333, 0.4583333333333333, 'gini = 0.0\nsamples = 12\nvalue = [12, 0, 0, 0, 0, 0]'),
#  Text(0.3645833333333333, 0.5416666666666666, 'x[1] <= 178.5\ngini = 0.434\nsamples = 22\nvalue = [0, 15, 7, 0, 0, 0]'),
#  Text(0.3541666666666667, 0.4583333333333333, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.375, 0.4583333333333333, 'x[1] <= 182.0\ngini = 0.117\nsamples = 16\nvalue = [0, 15, 1, 0, 0, 0]'),
#  Text(0.3645833333333333, 0.375, 'x[2] <= 59.5\ngini = 0.32\nsamples = 5\nvalue = [0, 4, 1, 0, 0, 0]'),
#  Text(0.3541666666666667, 0.2916666666666667, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0, 0, 0]'),
#  Text(0.375, 0.2916666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3854166666666667, 0.375, 'gini = 0.0\nsamples = 11\nvalue = [0, 11, 0, 0, 0, 0]'),
#  Text(0.4895833333333333, 0.625, 'x[1] <= 179.5\ngini = 0.321\nsamples = 37\nvalue = [0, 2, 30, 5, 0, 0]'),
#  Text(0.4479166666666667, 0.5416666666666666, 'x[0] <= 0.5\ngini = 0.496\nsamples = 11\nvalue = [0, 0, 6, 5, 0, 0]'),
#  Text(0.4166666666666667, 0.4583333333333333, 'x[2] <= 80.0\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 1, 0, 0]'),
#  Text(0.40625, 0.375, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.4270833333333333, 0.375, 'x[1] <= 176.0\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.4166666666666667, 0.2916666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.4375, 0.2916666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.4791666666666667, 0.4583333333333333, 'x[2] <= 79.0\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 4, 0, 0]'),
#  Text(0.46875, 0.375, 'x[1] <= 174.0\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.4583333333333333, 0.2916666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.4791666666666667, 0.2916666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.4895833333333333, 0.375, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.53125, 0.5416666666666666, 'x[2] <= 69.5\ngini = 0.142\nsamples = 26\nvalue = [0, 2, 24, 0, 0, 0]'),
#  Text(0.5208333333333334, 0.4583333333333333, 'x[1] <= 193.0\ngini = 0.5\nsamples = 4\nvalue = [0, 2, 2, 0, 0, 0]'),
#  Text(0.5104166666666666, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.53125, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.5416666666666666, 0.4583333333333333, 'gini = 0.0\nsamples = 22\nvalue = [0, 0, 22, 0, 0, 0]'),
#  Text(0.6705729166666666, 0.7916666666666666, 'x[1] <= 164.0\ngini = 0.667\nsamples = 175\nvalue = [0, 0, 6, 41, 76, 52]'),
#  Text(0.5833333333333334, 0.7083333333333334, 'x[2] <= 97.5\ngini = 0.312\nsamples = 62\nvalue = [0, 0, 0, 0, 12, 50]'),
#  Text(0.5625, 0.625, 'x[1] <= 145.0\ngini = 0.497\nsamples = 24\nvalue = [0, 0, 0, 0, 11, 13]'),
#  Text(0.5520833333333334, 0.5416666666666666, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 0, 0, 8]'),
#  Text(0.5729166666666666, 0.5416666666666666, 'x[2] <= 91.0\ngini = 0.43\nsamples = 16\nvalue = [0, 0, 0, 0, 11, 5]'),
#  Text(0.5625, 0.4583333333333333, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 7, 0]'),
#  Text(0.5833333333333334, 0.4583333333333333, 'x[1] <= 152.0\ngini = 0.494\nsamples = 9\nvalue = [0, 0, 0, 0, 4, 5]'),
#  Text(0.5729166666666666, 0.375, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 0, 4]'),
#  Text(0.59375, 0.375, 'x[1] <= 156.0\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 0, 0, 4, 1]'),
#  Text(0.5833333333333334, 0.2916666666666667, 'x[2] <= 94.0\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 0, 1, 1]'),
#  Text(0.5729166666666666, 0.20833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.59375, 0.20833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.6041666666666666, 0.2916666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.6041666666666666, 0.625, 'x[1] <= 160.5\ngini = 0.051\nsamples = 38\nvalue = [0, 0, 0, 0, 1, 37]'),
#  Text(0.59375, 0.5416666666666666, 'gini = 0.0\nsamples = 34\nvalue = [0, 0, 0, 0, 0, 34]'),
#  Text(0.6145833333333334, 0.5416666666666666, 'x[2] <= 106.5\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 0, 1, 3]'),
#  Text(0.6041666666666666, 0.4583333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.625, 0.4583333333333333, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 3]'),
#  Text(0.7578125, 0.7083333333333334, 'x[1] <= 181.5\ngini = 0.544\nsamples = 113\nvalue = [0, 0, 6, 41, 64, 2]'),
#  Text(0.6927083333333334, 0.625, 'x[2] <= 94.5\ngini = 0.303\nsamples = 57\nvalue = [0, 0, 1, 7, 47, 2]'),
#  Text(0.65625, 0.5416666666666666, 'x[1] <= 173.0\ngini = 0.568\nsamples = 13\nvalue = [0, 0, 1, 6, 6, 0]'),
#  Text(0.6458333333333334, 0.4583333333333333, 'x[1] <= 168.5\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 1, 0, 6, 0]'),
#  Text(0.6354166666666666, 0.375, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.65625, 0.375, 'x[2] <= 89.0\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 0, 2, 0]'),
#  Text(0.6458333333333334, 0.2916666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.6666666666666666, 0.2916666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.6666666666666666, 0.4583333333333333, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.7291666666666666, 0.5416666666666666, 'x[2] <= 119.0\ngini = 0.129\nsamples = 44\nvalue = [0, 0, 0, 1, 41, 2]'),
#  Text(0.7083333333333334, 0.4583333333333333, 'x[1] <= 168.5\ngini = 0.05\nsamples = 39\nvalue = [0, 0, 0, 1, 38, 0]'),
#  Text(0.6979166666666666, 0.375, 'x[1] <= 167.5\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 0, 1, 5, 0]'),
#  Text(0.6875, 0.2916666666666667, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(0.7083333333333334, 0.2916666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.71875, 0.375, 'gini = 0.0\nsamples = 33\nvalue = [0, 0, 0, 0, 33, 0]'),
#  Text(0.75, 0.4583333333333333, 'x[1] <= 173.0\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 0, 0, 3, 2]'),
#  Text(0.7395833333333334, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(0.7604166666666666, 0.375, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.8229166666666666, 0.625, 'x[2] <= 114.5\ngini = 0.531\nsamples = 56\nvalue = [0, 0, 5, 34, 17, 0]'),
#  Text(0.8125, 0.5416666666666666, 'x[1] <= 198.5\ngini = 0.377\nsamples = 44\nvalue = [0, 0, 5, 34, 5, 0]'),
#  Text(0.8020833333333334, 0.4583333333333333, 'x[2] <= 105.5\ngini = 0.325\nsamples = 42\nvalue = [0, 0, 3, 34, 5, 0]'),
#  Text(0.78125, 0.375, 'x[1] <= 196.0\ngini = 0.225\nsamples = 32\nvalue = [0, 0, 3, 28, 1, 0]'),
#  Text(0.7708333333333334, 0.2916666666666667, 'x[2] <= 91.0\ngini = 0.179\nsamples = 31\nvalue = [0, 0, 2, 28, 1, 0]'),
#  Text(0.75, 0.20833333333333334, 'x[1] <= 188.5\ngini = 0.375\nsamples = 8\nvalue = [0, 0, 2, 6, 0, 0]'),
#  Text(0.7395833333333334, 0.125, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.7604166666666666, 0.125, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.7916666666666666, 0.20833333333333334, 'x[1] <= 182.5\ngini = 0.083\nsamples = 23\nvalue = [0, 0, 0, 22, 1, 0]'),
#  Text(0.78125, 0.125, 'x[2] <= 101.0\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.7708333333333334, 0.041666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7916666666666666, 0.041666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8020833333333334, 0.125, 'gini = 0.0\nsamples = 21\nvalue = [0, 0, 0, 21, 0, 0]'),
#  Text(0.7916666666666666, 0.2916666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8229166666666666, 0.375, 'x[1] <= 190.0\ngini = 0.48\nsamples = 10\nvalue = [0, 0, 0, 6, 4, 0]'),
#  Text(0.8125, 0.2916666666666667, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.8333333333333334, 0.2916666666666667, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.8229166666666666, 0.4583333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.8333333333333334, 0.5416666666666666, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 0, 0, 12, 0]'),
#  Text(0.9270833333333334, 0.875, 'x[1] <= 185.5\ngini = 0.305\nsamples = 176\nvalue = [0, 0, 0, 0, 33, 143]'),
#  Text(0.8854166666666666, 0.7916666666666666, 'x[1] <= 178.5\ngini = 0.082\nsamples = 140\nvalue = [0, 0, 0, 0, 6, 134]'),
#  Text(0.875, 0.7083333333333334, 'gini = 0.0\nsamples = 112\nvalue = [0, 0, 0, 0, 0, 112]'),
#  Text(0.8958333333333334, 0.7083333333333334, 'x[2] <= 135.0\ngini = 0.337\nsamples = 28\nvalue = [0, 0, 0, 0, 6, 22]'),
#  Text(0.8645833333333334, 0.625, 'x[2] <= 128.5\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 0, 0, 5, 1]'),
#  Text(0.8541666666666666, 0.5416666666666666, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.875, 0.5416666666666666, 'x[1] <= 181.0\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 0, 2, 1]'),
#  Text(0.8645833333333334, 0.4583333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.8854166666666666, 0.4583333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.9270833333333334, 0.625, 'x[2] <= 139.5\ngini = 0.087\nsamples = 22\nvalue = [0, 0, 0, 0, 1, 21]'),
#  Text(0.9166666666666666, 0.5416666666666666, 'x[1] <= 182.0\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 0, 1, 2]'),
#  Text(0.90625, 0.4583333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9270833333333334, 0.4583333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(0.9375, 0.5416666666666666, 'gini = 0.0\nsamples = 19\nvalue = [0, 0, 0, 0, 0, 19]'),
#  Text(0.96875, 0.7916666666666666, 'x[2] <= 139.5\ngini = 0.375\nsamples = 36\nvalue = [0, 0, 0, 0, 27, 9]'),
#  Text(0.9583333333333334, 0.7083333333333334, 'gini = 0.0\nsamples = 19\nvalue = [0, 0, 0, 0, 19, 0]'),
#  Text(0.9791666666666666, 0.7083333333333334, 'x[1] <= 196.5\ngini = 0.498\nsamples = 17\nvalue = [0, 0, 0, 0, 8, 9]'),
#  Text(0.96875, 0.625, 'x[2] <= 149.5\ngini = 0.426\nsamples = 13\nvalue = [0, 0, 0, 0, 4, 9]'),
#  Text(0.9583333333333334, 0.5416666666666666, 'x[1] <= 191.5\ngini = 0.494\nsamples = 9\nvalue = [0, 0, 0, 0, 4, 5]'),
#  Text(0.9479166666666666, 0.4583333333333333, 'x[2] <= 147.0\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 0, 0, 2, 5]'),
#  Text(0.9375, 0.375, 'x[1] <= 187.5\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 0, 0, 1, 5]'),
#  Text(0.9270833333333334, 0.2916666666666667, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 0, 4]'),
#  Text(0.9479166666666666, 0.2916666666666667, 'x[2] <= 143.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 0, 1, 1]'),
#  Text(0.9375, 0.20833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9583333333333334, 0.20833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.9583333333333334, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.96875, 0.4583333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.9791666666666666, 0.5416666666666666, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 0, 4]'),
#  Text(0.9895833333333334, 0.625, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]')]

# %%
pip install graphviz
# Out:
# Collecting graphviz
#   Obtaining dependency information for graphviz from https://files.pythonhosted.org/packages/00/be/d59db2d1d52697c6adc9eacaf50e8965b6345cc143f671e1ed068818d5cf/graphviz-0.20.3-py3-none-any.whl.metadata
#   Downloading graphviz-0.20.3-py3-none-any.whl.metadata (12 kB)
# Downloading graphviz-0.20.3-py3-none-any.whl (47 kB)
#    ---------------------------------------- 0.0/47.1 kB ? eta -:--:--
#    -------- ------------------------------- 10.2/47.1 kB ? eta -:--:--
#    -------------------------- ------------- 30.7/47.1 kB 435.7 kB/s eta 0:00:01
#    ---------------------------------------- 47.1/47.1 kB 338.4 kB/s eta 0:00:00
# Installing collected packages: graphviz
# Successfully installed graphviz-0.20.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import graphviz
data = tree.export_graphviz(model1, out_file=None, filled = True)
graph = graphviz.Source(data, formate = 'png')
graph
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 3
#       1 import graphviz
#       2 data = tree.export_graphviz(model1, out_file=None, filled = True)
# ----> 3 graph = graphviz.Source(data, formate = 'png')
#       4 graph
#
# File C:\Python311\Lib\site-packages\graphviz\_tools.py:171, in deprecate_positional_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     162     wanted = ', '.join(f'{name}={value!r}'
#     163                        for name, value in deprecated.items())
#     164     warnings.warn(f'The signature of {func.__name__} will be reduced'
#     165                   f' to {supported_number} positional args'
#     166                   f' {list(supported)}: pass {wanted}'
#     167                   ' as keyword arg(s)',
#     168                   stacklevel=stacklevel,
#     169                   category=category)
# --> 171 return func(*args, **kwargs)
#
# TypeError: Source.__init__() got an unexpected keyword argument 'formate'

# %%
graph.render('tree1.png')
